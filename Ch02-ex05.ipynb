# %%
import os

if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py

# %%
#設立function
def filter_spectrum(spectrum):
    """Divides the spectrum through by the fs.
    
    spectrum: Spectrum object
    """
    # avoid division by 0
    spectrum.hs[1:] /= spectrum.fs[1:]
    spectrum.hs[0] = 0

# %%
from thinkdsp import SquareSignal
from thinkdsp import decorate

wave = SquareSignal(freq=400).make_wave(duration=0.5)
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrum = wave.make_spectrum()
spectrum.plot(high=10000, color='orange')
filter_spectrum(spectrum)
spectrum.scale(400)
spectrum.plot(high=10000)
decorate(xlabel='Frequency (Hz)')

# %%
filtered = spectrum.make_wave()
filtered.make_audio() #較悶
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from thinkdsp import TriangleSignal

wave = TriangleSignal(freq=400).make_wave(duration=0.5)
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrum = wave.make_spectrum()
spectrum.plot(high=10000, color='orange')
filter_spectrum(spectrum)
spectrum.scale(400)
spectrum.plot(high=10000)
decorate(xlabel='Frequency (Hz)')

# %%
filtered = spectrum.make_wave()
filtered.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from thinkdsp import SawtoothSignal

wave = SawtoothSignal(freq=400).make_wave(duration=0.5)
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrum = wave.make_spectrum()
spectrum.plot(high=5000, color='orange')
filter_spectrum(spectrum)
spectrum.scale(400)
spectrum.plot(high=5000)
decorate(xlabel='Frequency (Hz)')

# %%
filtered = spectrum.make_wave()
filtered.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
